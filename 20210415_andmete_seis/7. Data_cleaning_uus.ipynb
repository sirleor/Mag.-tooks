# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv("PohitabelET1.csv")
data.head(20)
# Out:
#                      Tag                                         Lõigu sisu  \
# 0              C19Centre                  EUROOPA KOHTU OTSUS (neljas koda)
# 1              C19Centre                                 17. detsember 2020
# 2          C71Indicateur  Eelotsusetaotlus – Eelotsuse kiirmenetlus – Po...
# 3          C02AlineaAltA                                                 TR
# 4          C02AlineaAltA                 Generalstaatsanwaltschaft Hamburg,
# 5      C42FootnoteLangue                                              saksa
# 6           C03Tiretlong  –        Generalstaatsanwaltschaft Hamburg, es...
# 7           C03Tiretlong  –        Saksamaa valitsus, esindajad: J. Möll...
# 8           C03Tiretlong  –        Rumeenia valitsus, esindajad: E. Gane...
# 9           C03Tiretlong  –        Poola valitsus, esindajad: B. Majczyn...
# 10          C03Tiretlong  –        Euroopa Komisjon, esindajad: C. Laden...
# ...

# %%
#Vaatan kui palju on unikaalseid kohtuasja nr-d
data.Kohtuasja_ID.nunique()
# Out:
# 8003

# %%
#Sean need listiks, et oleks hiljem võimalik võrrelda, kas olen kõik kohtuasjad läbi käinud, leidmaks algused ja lõpud
unikaalsed_kogu=data.Kohtuasja_ID.unique().tolist()
unikaalsed_kogu1=set(unikaalsed_kogu)

# %%
# Selle koodiga vaatasin andmeid (kohtuasja ID järgi ja mille Pealkirju pole), et 
#saada kätte see koht, kust algab kohtu hinnang, mis oli erinevalt sõnastatud
data[(data.Kohtuasja_ID==22300) & (data.Pealkiri1.isnull())].tail(60)
#Mõned näited, mille all kohtu hinnang oli:
# ID=0 - Eelotsuse küsimuse analüüs; C04Titre1; järgneb C01PointnumeroteAltN; C04Titre1 on eelnevalt rohkem
# 1 - Eelotsuse küsimuste analüüs; C05Titre2; järgneb C01PointnumeroteAltN; C05Titre2 on eelnevalt rohkem
# 2 - Eelotsuse küsimuste analüüs; C04Titre1; C01PointnumeroteAltN;  C04Titre1 on eelnevalt rohkem
# 3 - Eelotsuse küsimuste analüüs; C04Titre1; C01PointnumeroteAltN;
# 4 - Eelotsuse küsimuste analüüs; C04Titre1; C01PointnumeroteAltN;
# 15 - Euroopa Kohtu hinnang; C05Titre2, C01PointnumeroteAltN;
# 16 - Eelotsuse küsimuste analüüs,  C04Titre1; C01PointnumeroteAltN;
# 17 - Eelotsuse küsimuste analüüs,  C04Titre1; C01PointnumeroteAltN;
# 18 - – Euroopa Kohtu hinnang, C07Titre4, C01PointnumeroteAltN;
# 19 - Eelotsuse küsimuste analüüs,  C04Titre1; C01PointnumeroteAltN;
# 20 - Eelotsuse küsimuste analüüs,  C04Titre1; C01PointnumeroteAltN;
# 100 - Eelotsuse küsimuse analüüs, C04Titre1, C05Titre2
# 105 - Eelotsuse küsimuste analüüs,  C04Titre1; C01PointnumeroteAltN;
# 250 - Eelotsuse küsimuse analüüs, C04Titre1, C05Titre2
# 1000 - Eelotsuse küsimuste analüüs,  C04Titre1; C01PointnumeroteAltN;
# 2000 - Eelotsuse küsimuste analüüs,  C04Titre1; C01PointnumeroteAltN;
# 10011 - Eelotsuse küsimus, C04Titre1; C01PointnumeroteAltN;
# 20200 - – Üldkohtu hinnang, C07Titre4; C01PointnumeroteAltN;
# 22120 - Esimese Astme Kohtu hinnang ;  C05Titre2; C01PointnumeroteAltN
#22300 -Esimese Astme Kohtu hinnang; C06Titre3; ; C01PointnumeroteAltN
#Titre-d on liiga erinevad, mistõttu on mõistlik otsida hinnang või analüüs järgi, 
#kuid sisse võib jääda ka alama astme pealkirju, mida võib olla vaja eemaldada omakorda!
# Out:
#                           Tag  \
# 1017209  C01PointnumeroteAltN
# 1017210  C01PointnumeroteAltN
# 1017211  C01PointnumeroteAltN
# 1017212  C01PointnumeroteAltN
# 1017213  C01PointnumeroteAltN
# 1017214  C01PointnumeroteAltN
# 1017215  C01PointnumeroteAltN
# 1017216  C01PointnumeroteAltN
# 1017217  C01PointnumeroteAltN
# 1017218  C01PointnumeroteAltN
# 1017219  C01PointnumeroteAltN
# 1017220  C01PointnumeroteAltN
# 1017221  C01PointnumeroteAltN
# 1017222  C01PointnumeroteAltN
# 1017223  C01PointnumeroteAltN
# 1017224  C01PointnumeroteAltN
# 1017225  C01PointnumeroteAltN
# 1017226  C01PointnumeroteAltN
# 1017227  C01PointnumeroteAltN
# 1017228  C01PointnumeroteAltN
# 1017229  C01PointnumeroteAltN
# 1017230  C01PointnumeroteAltN
# 1017231  C01PointnumeroteAltN
# 1017232  C01PointnumeroteAltN
# 1017233  C01PointnumeroteAltN
# 1017234  C01PointnumeroteAltN
# 1017235  C01PointnumeroteAltN
# 1017236             C06Titre3
# 1017237  C01PointnumeroteAltN
# 1017238  C01PointnumeroteAltN
# ...

# %%
#Need pealkirjad on vajalikud selleks, et sealt algab enamasti EL kohtulahendites kohtu hinnang ehk mida juristid esimesena loevad!
#Seda koodi kasutades ja pealkirjasid juurde otsides allpool olevate koodide abil, leidsin hulga, 
#mille lõigu sisu ei ole tühi, pealkiri on tühi ja lõigu sisu on kohtu hinnang selle erinevas väljenduses.
#Seadsin nende lõikude kohtuasja nr-d ka listi, et võrrelda algsete kohtuasja nr-tega, et
#teaksin millistes lahendites neid sõnu ei leidu ja 
# saaksin edasi puhastades kätte kõik vajalikud pealkirjad, kus hinnang sisaldub.
frame=data[(data['Lõigu sisu'].isnull()==False)&
           (data.Pealkiri1.isnull())&((data['Lõigu sisu']==' Euroopa Kohtu hinnang') |
                                      (data['Lõigu sisu']==' Euroopa Kohtu hinnang ') |
                                      (data['Lõigu sisu']=='Euroopa Kohtu hinnang') |
                                      (data['Lõigu sisu']==' – Euroopa Kohtu hinnang') | 
                                      (data['Lõigu sisu']=='–       Euroopa Kohtu hinnang') |
                                      (data['Lõigu sisu']=='2)      Euroopa Kohtu hinnang') | 
                                      (data['Lõigu sisu']=='2.      Euroopa Kohtu hinnang') | 
                                      (data['Lõigu sisu']=='2.     Euroopa Kohtu hinnang') | 
                                      (data['Lõigu sisu']==' 2. Euroopa Kohtu hinnang') | 
                                      (data['Lõigu sisu']=='b)      Euroopa Kohtu hinnang') |
                                      (data['Lõigu sisu']=='b)     Euroopa Kohtu hinnang') |
                                      (data['Lõigu sisu']=='B.      Euroopa Kohtu hinnang') |
                                      (data['Lõigu sisu']=='B –  Euroopa Kohtu hinnang') | 
                                      (data['Lõigu sisu']=='III –  Euroopa Kohtu hinnang') |
                                      (data['Lõigu sisu']==' Kohtu hinnang') |
                                      (data['Lõigu sisu']==' Esimese Astme Kohtu hinnang') |
                                      (data['Lõigu sisu']==' Esimese Astme Kohtu hinnang') | 
                                      (data['Lõigu sisu']==' Avaliku Teenistuse Kohtu hinnang') | 
                                      (data['Lõigu sisu']==' Üldkohtu hinnang') |
                                      (data['Lõigu sisu']==' – Üldkohtu hinnang') |
                                      (data['Lõigu sisu']==' b. Avaliku Teenistuse Kohtu hinnang') |
                                      (data['Lõigu sisu']=='–       Avaliku Teenistuse Kohtu hinnang') | 
                                      (data['Lõigu sisu']=='B –  Esimese Astme Kohtu hinnang') |
                                      (data['Lõigu sisu']==' Euroopa Kohtu vastus') | 
                                      #(data['Lõigu sisu']==' Õiguslik käsitlus') | 
                                      #(data['Lõigu sisu']==' Õiguslik käsitlus ') |
                                      #(data['Lõigu sisu']=='III. Õiguslik käsitlus') |
                                      #(data['Lõigu sisu']=='IV.    Õiguslik käsitlus') |
                                      #(data['Lõigu sisu']=='V.      Õiguslik käsitlus') | 
                                      (data['Lõigu sisu']==' Euroopa Kohtu analüüs') |                     
                                      (data['Lõigu sisu']==' Õiguslik analüüs') | 
                                      #(data['Lõigu sisu']==' Põhikohtuasi ja eelotsuse küsimus') | 
                                      #(data['Lõigu sisu']==' Põhikohtuasi ja eelotsuse küsimused') | 
                                      (data['Lõigu sisu']==' Eelotsuse küsimus') |
                                      (data['Lõigu sisu']==' Eelotsuse küsimus ') |
                                      (data['Lõigu sisu']==' Eelotsuse küsimused') |
                                      (data['Lõigu sisu']==' Eelotsuse küsimused ') | 
                                      (data['Lõigu sisu']==' Eelotsuse küsimuse analüüs') | 
                                      (data['Lõigu sisu']==' Eelotsuse küsimuste analüüs') |
                                      (data['Lõigu sisu']==' Eelotsusetaotluste analüüs') |
                                      (data['Lõigu sisu']=='III. Eelotsuse küsimuste analüüs') |
                                      (data['Lõigu sisu']=='III –  Eelotsuse küsimuste analüüs') |
                                      #(data['Lõigu sisu']==' III – Eelotsuse küsimused') |
                                      #(data['Lõigu sisu']=='III –  Eelotsuse küsimused') |
                                      (data['Lõigu sisu']==' Esimese eelotsuse küsimuse analüüs') )]#|
                                      #(data['Lõigu sisu']==' Küsimused') |
                                      #(data['Lõigu sisu']==' Põhiküsimus') |
                                      #(data['Lõigu sisu']==' 1.     Lähteküsimus') |
                                      #(data['Lõigu sisu']==' Esimene küsimus') |
                                      #(data['Lõigu sisu']==' a)     Esimene küsimus') |
                                      #(data['Lõigu sisu']==' Esimene küsimus ') | 
                                      #(data['Lõigu sisu']==' Esimene väide') | 
                                      #(data['Lõigu sisu']==' Esimene ja teine küsimus') | 
                                      #(data['Lõigu sisu']=='C.      Esimene ja teine küsimus') | 
                                      #(data['Lõigu sisu']==' Kaks esimest eelotsuse küsimust') |
                                      #(data['Lõigu sisu']==' Esimene, kolmas ja neljas küsimus ') |
                                      #(data['Lõigu sisu']==' Esimene, teine ja kolmas küsimus') |
                                      #(data['Lõigu sisu']==' Esimesed kolm küsimust') |
                                      #(data['Lõigu sisu']==' Hagi') | 
                                      #(data['Lõigu sisu']==' Hagi ') | 
                                      #(data['Lõigu sisu']=='III –  Hagi') |
                                      #(data['Lõigu sisu']==' Hagimenetlus Üldkohtus') |
                                      #(data['Lõigu sisu']==' Apellatsioonkaebus') |
                                      #(data['Lõigu sisu']==' Apellatsioonkaebused') |
                                      #(data['Lõigu sisu']==' Apellatsioonkaebused') |
                                      #(data['Lõigu sisu']=='IV –  Apellatsioonkaebus') |
                                      #(data['Lõigu sisu']==' VI – Apellatsioonkaebused') |
                                      #(data['Lõigu sisu']=='V –  Apellatsioonkaebus') |
                                      #(data['Lõigu sisu']==' Tühistamisnõue') | 
                                      #(data['Lõigu sisu']==' Sisu') | 
                                      #(data['Lõigu sisu']==' Sisulised küsimused') | 
                                      #(data['Lõigu sisu']==' Vastuvõetavus') |
                                      #(data['Lõigu sisu']=='III. Vastuvõetavus') |
                                      #(data['Lõigu sisu']==' Eelotsusetaotluse vastuvõetavus') | 
                                      #(data['Lõigu sisu']==' Hagi vastuvõetavus') |
                                      #(data['Lõigu sisu']==' Hagi vastuvõetavus ') |
                                      #(data['Lõigu sisu']==' Kolme esimese eelotsuse küsimuse vastuvõetavus') |
                                      #(data['Lõigu sisu']==' Eelotsuse küsimuste vastuvõetavus') |
                                      #(data['Lõigu sisu']==' Menetlus Euroopa Kohtus') | 
                                      #(data['Lõigu sisu']==' Uuesti läbivaatamine') | 
                                      #(data['Lõigu sisu']==' Menetluse suulise osa uuendamise taotlus') | 
                                      #(data['Lõigu sisu']==' Euroopa Kohtu pädevus') | 
                                      #(data['Lõigu sisu']==' Vaidlustatud otsuse tühistamise nõue') | 
                                      #(data['Lõigu sisu']==' Esialgsed tähelepanekud') | 
                                      #(data['Lõigu sisu']==' Esialgsed märkused') | 
                                      #(data['Lõigu sisu']==' Kiirmenetlus') |
                                      #(data['Lõigu sisu']==' Uurimise alustamise otsus') | 
                                      #(data['Lõigu sisu']=='II –  Euroopa Kohtu pädevus') |
                                      #(data['Lõigu sisu']==' Suulise menetluse uuendamise taotlus') | 
                                      #(data['Lõigu sisu']==' Prantsuse valitsuse teisesed nõuded') | 
                                      #(data['Lõigu sisu']==' Direktiivi artikli 7 lõiget 1 käsitlevad küsimused') | 
                                      #(data['Lõigu sisu']==' Direktiivi 93/83 kohaldatavus') | 
                                      #(data['Lõigu sisu']==' EMÜ asutamislepingu artikli 52 tõlgendamine') | 
                                      #(data['Lõigu sisu']==' Vaidlusese') | 
                                      #(data['Lõigu sisu']==' Vaidlustatud määruse tühistamise nõue') | 
                                      #(data['Lõigu sisu']==' Liikmesriigi kohustuste rikkumine') | 
                                      #(data['Lõigu sisu']==' Taganemisõigust käsitlevate direktiivi sätete tingimusteta ja piisavalt täpne olemus') | 
                                      #(data['Lõigu sisu']==' Riigivastutus liikmesriigi seadusandja tegude ja tegevusetuse eest, mis on vastuolus ühenduse õigusega (nii kohtuasja C\xad46/93 kui ka C-48/93 esimene küsimus)') | 
                                      #(data['Lõigu sisu']==' Esimene küsimus (artikli 119 vahetu õigusmõju)') | 
                                      #(data['Lõigu sisu']==' Õigus tõhusale kohtulikule kaitsele') | 
                                      #(data['Lõigu sisu']==' Töötajate õigusi määratlevate direktiivi sätete vahetu õigusmõju') |
                                      #(data['Lõigu sisu']==' Menetlustoimingute taotlus') | 
                                      #(data['Lõigu sisu']==' Ühenduse määrusel põhineva siseriikliku õigusakti täitmise peatamine') |
                                      #(data['Lõigu sisu']==' Esimene väide, et on rikutud määruse nr 1306/2013 artiklit 52 ja määruse nr 885/2006 artikli 11 lõiget 1'))] 
unikaalsed_IDd=frame.Kohtuasja_ID.unique().tolist()
unikaalsed_ID_d_filter=set(unikaalsed_IDd)
frame
# Out:
#                       Tag                                Lõigu sisu Pealkiri1  \
# 69              C04Titre1                Eelotsuse küsimuse analüüs       NaN
# 163             C04Titre1               Eelotsuse küsimuste analüüs       NaN
# 289             C04Titre1               Eelotsuse küsimuste analüüs       NaN
# 394             C04Titre1                Eelotsuse küsimuse analüüs       NaN
# 469             C04Titre1                Eelotsuse küsimuse analüüs       NaN
# ...                   ...                                       ...       ...
# 1031516  C23Niveau5titre3          Avaliku Teenistuse Kohtu hinnang       NaN
# 1031668         C07Titre4  –       Avaliku Teenistuse Kohtu hinnang       NaN
# 1031706         C07Titre4  –       Avaliku Teenistuse Kohtu hinnang       NaN
# 1031725         C06Titre3          Avaliku Teenistuse Kohtu hinnang       NaN
# 1031837         C06Titre3          Avaliku Teenistuse Kohtu hinnang       NaN
#
# ...

# %%
#Selle koodi abil leidsin, millised kohtuasja nr-d on veel läbi käimata, kus kohtu hinnang võiks olla teisiti nimetatud
len(unikaalsed_kogu1-unikaalsed_ID_d_filter)
# Osad jäid veel alles järgmistel põhjustel:
#2764, - C02AlineaAltA all, muidu pole tagitud
# 3010- C02AlineaAltA all, muidu pole tagitud
# 6803- ainult üks C04Titre1- siis pole alampealkirju ja kogu lahend tuleks võtta otsitavaks!
# 7182,- ainult üks C04Titre1- siis pole alampealkirju ja kogu lahend tuleks võtta otsitavaks!
# 10415,- ainult üks C04Titre1- siis pole alampealkirju ja kogu lahend tuleks võtta otsitavaks!
# 10960,- ainult üks C04Titre1- siis pole alampealkirju ja kogu lahend tuleks võtta otsitavaks!
# 11093,- ainult üks C04Titre1- siis pole alampealkirju ja kogu lahend tuleks võtta otsitavaks!
# 11571,- ainult üks C04Titre1- siis pole alampealkirju ja kogu lahend tuleks võtta otsitavaks!
# 12198,- ainult üks C04Titre1- siis pole alampealkirju ja kogu lahend tuleks võtta otsitavaks!
# 12474,- ainult üks C04Titre1- siis pole alampealkirju ja kogu lahend tuleks võtta otsitavaks!
# 12813,- ainult üks C04Titre1- siis pole alampealkirju ja kogu lahend tuleks võtta otsitavaks!
# 13119,- ainult üks C04Titre1- siis pole alampealkirju ja kogu lahend tuleks võtta otsitavaks!
# 13664,- ainult üks C04Titre1- siis pole alampealkirju ja kogu lahend tuleks võtta otsitavaks!
# 14912,- ainult üks C04Titre1- siis pole alampealkirju ja kogu lahend tuleks võtta otsitavaks!
# 15414,- ainult üks C04Titre1- siis pole alampealkirju ja kogu lahend tuleks võtta otsitavaks!
# 16876, - välja jätta, sest ainult pealkirjad on salvestunud
# 16926,- välja jätta, sest ainult pealkirjad on salvestunud
# 17002,- välja jätta, sest ainult pealkirjad on salvestunud
# 17223,- välja jätta, sest osad andmed pole salvestunud
# 17573,- välja jätta, sest osad andmed pole salvestunud
# 17652,- välja jätta, sest osad andmed pole salvestunud
# 17715,- välja jätta, sest osad andmed pole salvestunud
# 17781,- välja jätta, sest osad andmed pole salvestunud
# 18385,- välja jätta, sest osad andmed pole salvestunud
# 18431,- välja jätta, sest osad andmed pole salvestunud
# 18636,- välja jätta, sest osad andmed pole salvestunud
# 18639,- välja jätta, sest osad andmed pole salvestunud
# 18668,- välja jätta, sest osad andmed pole salvestunud
# 19100- ainult üks C04Titre1- siis pole alampealkirju ja kogu lahend tuleks võtta otsitavaks!
# Out:
# 1565

# %%
#Kasutades tail/head või loc järgmisi koodiosi otsisin käsitsi õigeid kohtu hinnangu algusele viitavaid sõnu neist
# lahendeist, mis ei tulnud nt "Euroopa Kohtu hinnang" otsinguga välja, sest olid teisiti sõnastatud.
#Selle tulemusena täiendasin alguse sõnade listi
#data[(data.Kohtuasja_ID==0)].head(40)
#data[(data.Kohtuasja_ID==0)].tail(40)
#data[(data.Pealkiri1.isnull())].loc[212880]['Lõigu sisu']

# %%
# Osade kohtulahendite hinnangu osa lõppeb kohtukulude määramisega. Seda osa ei ole samamoodi vaja.
# Ka seda võis olla erinevas vormis. Seetõttu tuli kõik kohtukulude erinevad vormid üles leida.
frame2=data[(data['Lõigu sisu']==' Kohtukulud') |
            (data['Lõigu sisu']=='Kohtukulud') |
            (data['Lõigu sisu']==' Kohtukulud ') |
            (data['Lõigu sisu']=='  Kohtukulud') |
           (data['Lõigu sisu']=='VII. Kohtukulud') |
           (data['Lõigu sisu']=='IV.    Kohtukulud')|
           (data['Lõigu sisu']=='VI.    Kohtukulud')|
           (data['Lõigu sisu']==' VIII.      Kohtukulud')|
           (data['Lõigu sisu']=='42      Kohtukulud') |
            (data['Lõigu sisu']==' VI.      Kohtukulud') |
            (data['Lõigu sisu']=='IV –  Kohtukulud') |
            (data['Lõigu sisu']=='VI –  Kohtukulud') |
            (data['Lõigu sisu']=='VIII –  Kohtukulud') |
            (data['Lõigu sisu']=='V –  Kohtukulud') |
            (data['Lõigu sisu']=='VII –  Kohtukulud') |
            (data['Lõigu sisu']==' IV – Kohtukulud') |
            (data['Lõigu sisu']=='VI –  Kohtukulud') |
            (data['Lõigu sisu']=='49      Kohtukulud') |
            (data['Lõigu sisu']==' VI     Kohtukulud') |
            (data['Lõigu sisu']==' Kulude kohta')|
            (data['Lõigu sisu']==' VII – Kohtukulud')|
            (data['Lõigu sisu']==' Kulud') |
            (data['Lõigu sisu']=='III –  Kohtukulud') |
            (data['Lõigu sisu']==' 4.     Kohtukulud') |
            (data['Lõigu sisu']==' IV.      Kohtukulud') | 
            (data['Lõigu sisu']=='V.      Kohtukulud') |
            (data['Lõigu sisu']==' V.      Kohtukulud') |
           (data['Lõigu sisu']=='VI – Kohtukulud')]
unikaalsed_lõpud2=set(frame2.Kohtuasja_ID.unique().tolist())

# %%
# Selle koodi abil leidsin, millistes lahendites kohtukulud puuduvad. Kasutasin eelnevalt toodud head/tail/loc,
# et vaadelda kohtuotsuste osasid (lõike)
(unikaalsed_kogu1-unikaalsed_lõpud2)
# Neis lahendites, mis siin järele on jäänud, kohtukulude osa ei ole eraldi kirjas.
# Out:
# {451,
#  729,
#  1624,
#  1741,
#  1908,
#  1945,
#  2099,
#  2337,
#  2386,
#  2508,
#  2647,
#  2709,
#  2831,
#  3689,
#  3753,
#  3907,
#  4023,
#  4231,
#  4242,
#  4247,
#  4248,
#  4554,
#  4662,
#  4931,
#  5319,
#  6233,
#  6259,
#  6261,
#  6390,
#  6402,
#  6461,
#  6531,
#  6684,
#  6933,
#  7017,
#  7030,
#  7238,
#  7308,
#  7916,
#  7925,
#  15414,
#  17149,
#  17154,
#  17162,
#  17164,
#  17171,
#  17176,
#  17191,
#  17209,
#  17211,
#  17223,
#  17234,
#  17240,
#  17260,
#  17265,
#  17278,
#  17280,
#  17308,
#  17318,
#  17332,
#  17337,
#  17363,
#  17386,
#  17394,
#  17403,
#  17408,
#  17535,
#  17555,
#  17573,
#  17577,
#  17613,
#  17618,
#  17624,
#  17629,
#  17670,
#  17672,
#  17674,
#  17680,
#  17694,
#  17754,
#  17758,
#  17764,
#  17781,
#  17785,
#  17794,
#  17837,
#  17876,
#  17912,
#  17968,
#  17975,
#  17995,
#  17997,
#  18011,
#  18039,
#  18058,
#  18090,
#  18116,
#  18118,
#  18120,
#  18147,
#  18159,
#  18187,
#  18217,
#  18227,
# ...

# %%
#Leidnud alguse ja lõpu pealkirjad tuli need eraldi ära märgendada, et filtreerida välja ainult sobivad kohtulahendite osad
alguse_tagid=set(frame['Lõigu sisu'].to_list())
data['algus_lopp']=np.where(data['Lõigu sisu'].isin(alguse_tagid), 'algus', None)
data
# Out:
#                                Tag  \
# 0                        C19Centre
# 1                        C19Centre
# 2                    C71Indicateur
# 3                    C02AlineaAltA
# 4                    C02AlineaAltA
# ...                            ...
# 1031875       C01PointnumeroteAltN
# 1031876  C48DispositifIntroduction
# 1031877              C08Dispositif
# 1031878              C08Dispositif
# 1031879              C08Dispositif
#
#                                                 Lõigu sisu     Pealkiri1  \
# 0                        EUROOPA KOHTU OTSUS (neljas koda)          Koda
# 1                                       17. detsember 2020       Kuupaev
# 2        Eelotsusetaotlus – Eelotsuse kiirmenetlus – Po...        Viited
# 3                                                       TR  Poolte_nimed
# 4                       Generalstaatsanwaltschaft Hamburg,  Poolte_nimed
# ...                                                    ...           ...
# ...

# %%
lopu_tagid=set(frame2['Lõigu sisu'].to_list())
data['algus_lopp']=np.where(data['Lõigu sisu'].isin(lopu_tagid), 'lopp', data['algus_lopp'])
data
# Out:
#                                Tag  \
# 0                        C19Centre
# 1                        C19Centre
# 2                    C71Indicateur
# 3                    C02AlineaAltA
# 4                    C02AlineaAltA
# ...                            ...
# 1031875       C01PointnumeroteAltN
# 1031876  C48DispositifIntroduction
# 1031877              C08Dispositif
# 1031878              C08Dispositif
# 1031879              C08Dispositif
#
#                                                 Lõigu sisu     Pealkiri1  \
# 0                        EUROOPA KOHTU OTSUS (neljas koda)          Koda
# 1                                       17. detsember 2020       Kuupaev
# 2        Eelotsusetaotlus – Eelotsuse kiirmenetlus – Po...        Viited
# 3                                                       TR  Poolte_nimed
# 4                       Generalstaatsanwaltschaft Hamburg,  Poolte_nimed
# ...                                                    ...           ...
# ...

# %%
#Lisaks tuli märge panna ka sinna, kus uus kohtulahend algab, sest osades lahendites kohtukulud lahendit ei lõpetanud
kohtuasja_vahetus=set(['Koda'])
kohtuasja_vahetus
data['algus_lopp']=np.where(data['Pealkiri1'].isin(kohtuasja_vahetus), 'vahetus', data['algus_lopp'])

# %%
# Samuti tuli märge panna ka sinna kus oli resolutsioon, sest ka see osa on otsingul oluline juristi jaoks
reso_tag=set(['Resolutsioon'])
data['algus_lopp']=np.where(data['Pealkiri1'].isin(reso_tag), 'algus', data['algus_lopp'])

# %%
# Vältimaks olukorda, kus kui algust ei leia, võtab filtreerimisse kogu lahendi, filtreerin välja need lahendid, kus algus on olemas
# kasutan unikaalsed_ID_d_filter määratlust
Algusega_frame=data[data.Kohtuasja_ID.isin(unikaalsed_ID_d_filter)]
Algusega_frame
# Out:
#                                Tag  \
# 0                        C19Centre
# 1                        C19Centre
# 2                    C71Indicateur
# 3                    C02AlineaAltA
# 4                    C02AlineaAltA
# ...                            ...
# 1031875       C01PointnumeroteAltN
# 1031876  C48DispositifIntroduction
# 1031877              C08Dispositif
# 1031878              C08Dispositif
# 1031879              C08Dispositif
#
#                                                 Lõigu sisu     Pealkiri1  \
# 0                        EUROOPA KOHTU OTSUS (neljas koda)          Koda
# 1                                       17. detsember 2020       Kuupaev
# 2        Eelotsusetaotlus – Eelotsuse kiirmenetlus – Po...        Viited
# 3                                                       TR  Poolte_nimed
# 4                       Generalstaatsanwaltschaft Hamburg,  Poolte_nimed
# ...                                                    ...           ...
# ...

# %%
# Seejärel tuli ffilliga täita kõik vahepealsed osad ehk algusest kuni "vahetuseni" või "lõpuni".
Algusega_frame['algus_lopp']=Algusega_frame.algus_lopp.fillna(method='ffill')
Algusega_frame.tail(40)
# Out:
# C:\Users\sirle\anaconda3\envs\py37\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#                                Tag  \
# 1031840       C01PointnumeroteAltN
# 1031841       C01PointnumeroteAltN
# 1031842       C01PointnumeroteAltN
# 1031843       C01PointnumeroteAltN
# 1031844       C01PointnumeroteAltN
# 1031845       C01PointnumeroteAltN
# 1031846       C01PointnumeroteAltN
# 1031847       C01PointnumeroteAltN
# 1031848       C01PointnumeroteAltN
# 1031849       C01PointnumeroteAltN
# 1031850       C01PointnumeroteAltN
# 1031851       C01PointnumeroteAltN
# 1031852       C01PointnumeroteAltN
# 1031853       C01PointnumeroteAltN
# 1031854       C01PointnumeroteAltN
# ...

# %%
#Kui filtreerida välja algused saame tabeli, kus otsitavate hulka on vähendatud ja täpsustatud.
filtreeritud_tabel=Algusega_frame[Algusega_frame.algus_lopp=='algus']
filtreeritud_tabel.tail(40)
# Out:
#                                Tag  \
# 1031840       C01PointnumeroteAltN
# 1031841       C01PointnumeroteAltN
# 1031842       C01PointnumeroteAltN
# 1031843       C01PointnumeroteAltN
# 1031844       C01PointnumeroteAltN
# 1031845       C01PointnumeroteAltN
# 1031846       C01PointnumeroteAltN
# 1031847       C01PointnumeroteAltN
# 1031848       C01PointnumeroteAltN
# 1031849       C01PointnumeroteAltN
# 1031850       C01PointnumeroteAltN
# 1031851       C01PointnumeroteAltN
# 1031852       C01PointnumeroteAltN
# 1031853       C01PointnumeroteAltN
# 1031854       C01PointnumeroteAltN
# 1031855       C01PointnumeroteAltN
# 1031856       C01PointnumeroteAltN
# 1031857       C01PointnumeroteAltN
# 1031858       C01PointnumeroteAltN
# 1031859       C01PointnumeroteAltN
# 1031860       C01PointnumeroteAltN
# 1031861       C01PointnumeroteAltN
# 1031862       C01PointnumeroteAltN
# 1031863       C01PointnumeroteAltN
# 1031864       C01PointnumeroteAltN
# ...

# %%
filtreeritud_tabel.Kohtuasja_ID.nunique() # tulemusena jäi järele 6438 kohtuasja
# Out:
# 6438

# %%
#Lõin eraldi filtreeritud tabelist csv faili, et ei peaks iga kord hakkama sama protseduuri kordama
#filtreeritud_tabel.to_csv("Pohitabel_filt_algusega.csv", index=False)

# %%
#ebavajalik osa

# %%
 Pealkirjad = ['C06Titre3', 'C27Niveau6titre2', 'C34Niveau7titre3', 'C04Titre1',   
                  'C06Titre4',  'C24Titre4', 'C23Titre3', 'C21Titrenumerote1', 'C21Titre1', 
                  'C28Niveau6titre3', 'C22Titrenumerote2', 'C21Niveau5titre1', 'C07Titre5', 
                  'C25Niveau5titre5',  'C26Titre6', 'C25Titrenumerote5', 
                  'C35Niveau7titre4', 'C22Niveau5titre2', 'C33Niveau7titre2',  'C24Titrenumerote4', 
                  'C22Titre2', 'C30Niveau6titre5', 'C23Niveau5titre3', 'C26Titrenumerote6', 'C05Titre2', 
                  'C29Niveau6titre4', 'C31Niveau6titre6', 'C27Titrenumerote7',  'C37Niveau7titre6',
                  'Cheading2', 'Cheading1', 'Cheading3', 'C23Titrenumerote3', 'C25Titre5', 'C07Titre4', 
                  'C24Niveau5titre4', 'C38Niveau7titre7', 'C36Niveau7titre5', 'C05Titre3',  
                  'C32Niveau7titre1', 'C26Niveau6titre1']
filtreeritud_tabel[filtreeritud_tabel.Tag.isin(set(Pealkirjad))].head(40)
# Out:
#             Tag                                         Lõigu sisu Pealkiri1  \
# 69    C04Titre1                         Eelotsuse küsimuse analüüs       NaN
# 163   C04Titre1                        Eelotsuse küsimuste analüüs       NaN
# 164   C05Titre2                                    Esimene küsimus       NaN
# 171   C05Titre2                                      Teine küsimus       NaN
# 183   C05Titre2                                     Kolmas küsimus       NaN
# 185   C06Titre3   Eelotsusetaotluse esitanud kohtu pädevus kont...       NaN
# 202   C06Titre3   Euroopa vahistamismääruse kehtetuks tunnistam...       NaN
# 289   C04Titre1                        Eelotsuse küsimuste analüüs       NaN
# 394   C04Titre1                         Eelotsuse küsimuse analüüs       NaN
# 469   C04Titre1                         Eelotsuse küsimuse analüüs       NaN
# 604   C04Titre1                        Eelotsuse küsimuste analüüs       NaN
# ...

# %%
#Ainult pealkirjad iga kohtulahendi kohta, millel oli rohkem kui 1 pealkiri otsingu tulemusena
#Nagu alltoodust näha, siis täielik nimekiri tähendab, et osades lahendites tuleb sisse ka ebavajalikku osa
#seega täpsemaks kalibreerimiseks tuleks vähendada alguse pealkirjade osa.
new=frame.Kohtuasja_ID.value_counts()>1
filtreeritud=new[new==True].index.tolist()
Mitmekordsed_pealkirjad=frame[frame.Kohtuasja_ID.isin(filtreeritud)]
Mitmekordsed_pealkirjad.head(40)
#Mitmekordsed_pealkirjad.Kohtuasja_ID.value_counts()
# Out:
#              Tag                     Lõigu sisu Pealkiri1  \
# 2069   C06Titre3          Euroopa Kohtu hinnang       NaN
# 2099   C07Titre4  –       Euroopa Kohtu hinnang       NaN
# 2130   C07Titre4  –       Euroopa Kohtu hinnang       NaN
# 2840   C06Titre3          Euroopa Kohtu hinnang       NaN
# 2868   C06Titre3          Euroopa Kohtu hinnang       NaN
# 2881   C06Titre3          Euroopa Kohtu hinnang       NaN
# 2892   C06Titre3          Euroopa Kohtu hinnang       NaN
# 2909   C06Titre3          Euroopa Kohtu hinnang       NaN
# 2920   C06Titre3          Euroopa Kohtu hinnang       NaN
# 2931   C06Titre3          Euroopa Kohtu hinnang       NaN
# 8347   C06Titre3          Euroopa Kohtu hinnang       NaN
# 8361   C07Titre4  –       Euroopa Kohtu hinnang       NaN
# 8379   C07Titre4  –       Euroopa Kohtu hinnang       NaN
# 8531   C06Titre3          Euroopa Kohtu hinnang       NaN
# 8547   C06Titre3          Euroopa Kohtu hinnang       NaN
# ...

# %%
#abilist võrdluseks
ls=Mitmekordsed_pealkirjad.index.tolist()
ls.insert(1031837, 0)
ls.remove(2069)
ls
# Out:
# [2099,
#  2130,
#  2840,
#  2868,
#  2881,
#  2892,
#  2909,
#  2920,
#  2931,
#  8347,
#  8361,
#  8379,
#  8531,
#  8547,
#  8572,
#  8594,
#  8604,
#  8625,
#  8643,
#  8655,
#  8669,
#  9719,
#  9735,
#  9788,
#  9822,
#  12206,
#  12219,
#  12229,
#  12241,
#  12256,
#  12491,
#  12508,
#  12523,
#  12553,
#  13970,
#  14030,
#  14567,
#  14588,
#  14615,
#  14629,
#  14644,
#  17310,
#  17340,
#  17353,
#  20331,
#  20353,
#  20375,
#  20388,
#  20401,
#  20421,
#  20698,
#  20728,
#  21210,
#  21226,
#  21241,
#  21256,
#  21447,
#  21460,
#  21482,
#  21505,
#  21518,
#  21528,
#  21544,
#  21748,
#  21778,
#  21878,
#  21894,
#  21919,
#  21944,
#  22282,
#  22307,
#  23873,
#  23908,
#  24480,
#  24500,
#  24518,
#  24528,
#  25213,
#  25236,
#  25257,
#  25277,
#  25362,
#  25377,
#  25396,
#  27356,
#  27404,
#  27419,
#  27496,
#  27517,
#  28306,
#  28330,
#  28361,
#  28724,
#  28735,
#  28754,
#  28789,
#  28803,
#  28924,
#  28961,
#  29495,
#  29528,
#  29539,
# ...

# %%
#Lisan võrdlusandmed tabelisse
Mitmekordsed_pealkirjad['abiindexid']=ls
Mitmekordsed_pealkirjad
# Out:
# C:\Users\sirle\anaconda3\envs\py37\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#                       Tag                                Lõigu sisu Pealkiri1  \
# 2069            C06Titre3                     Euroopa Kohtu hinnang       NaN
# 2099            C07Titre4             –       Euroopa Kohtu hinnang       NaN
# 2130            C07Titre4             –       Euroopa Kohtu hinnang       NaN
# 2840            C06Titre3                     Euroopa Kohtu hinnang       NaN
# 2868            C06Titre3                     Euroopa Kohtu hinnang       NaN
# ...                   ...                                       ...       ...
# ...

# %%
#Vaja on kätte saada need lahendid, kus pealkirju on rohkem kui 1, aga mis pole ka järjest.
uus=Mitmekordsed_pealkirjad[Mitmekordsed_pealkirjad.abiindexid!=Mitmekordsed_pealkirjad.index+1].Kohtuasja_ID.value_counts()>2
filtreeritud2=uus[uus==True].index.tolist()
Mitmekordsed_pealkirjad2=frame[frame.Kohtuasja_ID.isin(filtreeritud2)]
Mitmekordsed_pealkirjad2.tail(40)
# Out:
#                       Tag                                Lõigu sisu Pealkiri1  \
# 1028965  C25Niveau5titre5  –       Avaliku Teenistuse Kohtu hinnang       NaN
# 1029003  C24Niveau5titre4          Avaliku Teenistuse Kohtu hinnang       NaN
# 1029022  C25Niveau5titre5  –       Avaliku Teenistuse Kohtu hinnang       NaN
# 1029033  C25Niveau5titre5  –       Avaliku Teenistuse Kohtu hinnang       NaN
# 1029043  C24Niveau5titre4          Avaliku Teenistuse Kohtu hinnang       NaN
# 1029648  C37Niveau7titre6          Avaliku Teenistuse Kohtu hinnang       NaN
# 1029667  C37Niveau7titre6          Avaliku Teenistuse Kohtu hinnang       NaN
# 1029685  C37Niveau7titre6          Avaliku Teenistuse Kohtu hinnang       NaN
# 1029713  C37Niveau7titre6          Avaliku Teenistuse Kohtu hinnang       NaN
# 1029729  C37Niveau7titre6          Avaliku Teenistuse Kohtu hinnang       NaN
# 1029745  C38Niveau7titre7  –       Avaliku Teenistuse Kohtu hinnang       NaN
# ...

# %%
# Siin on näha, milline oli märgendamise tulemus pärast ffilli
data.algus_lopp.value_counts()
# Out:
# algus      39075
# vahetus     8003
# lopp        7869
# Name: algus_lopp, dtype: int64

# %%
#filtreeritud_tabel.to_csv("Pohitabel_filt.csv", index=False)

# %%
#vaatame filtreeritud tabeli osi
#filtreeritud_tabel.iloc[0:55,]
#data.iloc[48:55,]
