# %%
import pandas as pd
from sklearn.metrics.pairwise import cosine_similarity
import numpy as np

# %%
#pip install gensim==3.8.3

# %%
#Kolm erinevat varianti:
#Koondtabel_lemmadega.csv
#Koondtabel_lemmadega_ilma_resota.csv
#Koondtabel_lemmadega_ainult_reso.csv
data = pd.read_csv("Koondtabel_lemmadega.csv")
data
# Out:
#                               Tag  \
# 0            C01PointnumeroteAltN
# 1            C01PointnumeroteAltN
# 2            C01PointnumeroteAltN
# 3            C01PointnumeroteAltN
# 4            C01PointnumeroteAltN
# ...                           ...
# 317479       C01PointnumeroteAltN
# 317480  C48DispositifIntroduction
# 317481              C08Dispositif
# 317482              C08Dispositif
# 317483              C08Dispositif
#
#                                                Lõigu sisu     Pealkiri1  \
# 0       27      Kõigepealt väärib märkimist, et väljak...           NaN
# 1       28      Käesoleval juhul nähtub eelotsusetaotl...           NaN
# 2       29      Eelotsusetaotluse esitanud kohtu hinna...           NaN
# 3       30      Neil asjaoludel tuleb mõista eelotsuse...           NaN
# 4       31      Sellega seoses tuleb märkida, et nagu ...           NaN
# ...                                                   ...           ...
# 317479  95      Kõnesoleva hüvitise hindamisel tuleks ...           NaN
# 317480                    Esitatud põhjendustest lähtudes  Resolutsioon
# 317481  1.      Tühistada Euroopa Koolitusfondi 25. ju...  Resolutsioon
# 317482  2.      Pooled teatavad Avaliku Teenistuse Koh...  Resolutsioon
# 317483    3.      Otsus kohtukulude kohta tehakse hiljem.  Resolutsioon
#
#         Kohtuasja_nr  Kohtuasja_ID algus_lopp  \
# 0       C‑416/20 PPU             0      algus
# 1       C‑416/20 PPU             0      algus
# 2       C‑416/20 PPU             0      algus
# 3       C‑416/20 PPU             0      algus
# 4       C‑416/20 PPU             0      algus
# ...              ...           ...        ...
# 317479        F‑1/05         23801      algus
# 317480        F‑1/05         23801      algus
# 317481        F‑1/05         23801      algus
# 317482        F‑1/05         23801      algus
# 317483        F‑1/05         23801      algus
#
#                                           stop_eemaldatud  \
# 0       27 väärib märkimist väljakujunenud kohtuprakti...
# 1       28 käesoleval nähtub eelotsusetaotlusest eelot...
# 2       29 eelotsusetaotluse esitanud kohtu hinnangul ...
# 3       30 asjaoludel mõista eelotsusetaotluse esitanu...
# 4       31 seoses märkida nähtub raamotsuse 2002/584 a...
# ...                                                   ...
# 317479  95 kõnesoleva hüvitise hindamisel arvesse võtt...
# 317480                    esitatud põhjendustest lähtudes
# 317481  1. tühistada euroopa koolitusfondi 25. juuni 2...
# 317482  2. teatavad avaliku teenistuse kohtule kolme k...
# 317483                        3. otsus kohtukulude hiljem
#
#                                                     Lemma
# 0       27 väärima märkimine väljakujunenud kohtuprakt...
# 1       28 käesolev nähtuma eelotsusetaotlus eelotsuse...
# 2       29 eelotsusetaotlus esitama kohus hinnang ülea...
# 3       30 asjaolu mõistma eelotsusetaotlus esitama ko...
# 4       31 seos märkima nähtuma raamotsus 2002 / 584 a...
# ...                                                   ...
# 317479  95 kõnesolev hüvitis hindamine arve võtma p . ...
# 317480                          esitama põhjendus lähtuma
# 317481  1. tühistama euroopa koolitusfond 25. juuni 20...
# 317482  2. teatama avalik teenistus kohus kolm kuu käe...
# 317483                          3. otsus kohtukulu hiljem
#
# [317484 rows x 8 columns]

# %%
column_list=data['Lemma'].to_list()
column_list[0]
# Out:
# '27 väärima märkimine väljakujunenud kohtupraktika eltl artikkel 267 sätestama liikmesriik kohus euroopa kohus vaheline koostöömenetlus euroopa kohus ülesanne andma liikmesriik kohus tarvilik vastus võimaldama viimane pooleliolev kohtuasi lahendama arvestama euroopa kohus esitama küsimus vajadus sõnastama 2. aprill 2020. aasta kohtuotsus ruskama federacija c ‑ 897 / 19 ppu eu c : 2020 : 262 punkt 43 viidatud kohtupraktika'

# %%
from gensim import utils

class MyCorpus:
    """An iterator that yields sentences (lists of str)."""

    def __iter__(self):
        for x in column_list:
            yield str(x).split()

# %%
import gensim.models

sentences = MyCorpus() #lõhub lause tükkideks
model = gensim.models.Word2Vec(sentences=sentences, min_count=0) #treenib mudeli ette antud andmete peal

# %%
#Näidis ühe sõnaga
model.wv.most_similar('maks')
# Out:
# [('kapitalimaks', 0.7128840684890747),
#  ('käibemaks', 0.6845052242279053),
#  ('mootorsõidukimaks', 0.6815714240074158),
#  ('erimaks', 0.6774360537528992),
#  ('makse', 0.6637283563613892),
#  ('registreerimismaks', 0.6540635824203491),
#  ('viisanõu', 0.6277909278869629),
#  ('registreerimislõiv', 0.6249653697013855),
#  ('keskkonnalõiv', 0.6244661808013916),
#  ('aktsiis', 0.6234158873558044)]

# %%
#Näidis nr 2
model.wv.most_similar('käibemaksukohustuslane')
# Out:
# [('number', 0.7000703811645508),
#  ('soetaja', 0.6847562193870544),
#  ('sihtliikmesriik', 0.6096352338790894),
#  ('käibemaksumaksukohustuslane', 0.5981656312942505),
#  ('maksukohustuslane', 0.5969998836517334),
#  ('registreerimisnumber', 0.5968288779258728),
#  ('domeeninimi', 0.5817129611968994),
#  ('sisearve', 0.5658465623855591),
#  ('kviitung', 0.5618796944618225),
#  ('maksudeklaratsioon', 0.5512077212333679)]

# %%
# funktsioon pikemate lausevektorite loomiseks (sum)
def get_sum_vector(word2vec_model, words):
    words = [word for word in words if word in word2vec_model.wv.vocab]
    if len(words) >= 1:
        return np.sum(word2vec_model[words], axis=0)
    else:
        return []

# %%
# Käib kogu mudeli üle, selleks, et saada igast lõigust vektorid kasutades eelnevat funktsiooni get_sum_vector
sonad_arrays=[]
doc_jarjekord = []
for doc in sentences:
  #print(doc)
  vec = get_sum_vector(model, doc)
  sonad_arrays.append(vec)
  doc_jarjekord.append(doc)
# Out:
# C:\Users\sirle\anaconda3\envs\py37\lib\site-packages\ipykernel_launcher.py:5: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   """

# %%
#loodud proovilause, millega testida sarnasusi
listike='käibemaksukohustuslaseks registreerimine tinkivinki'

# %%
#Lemmaks
from estnltk import Text
text = Text(listike).tag_layer()
lemma_list = ' '.join([w[0] for w in text.morph_analysis.lemma])
lemma_list
# Out:
# 'käibemaksukohustuslane registreerimine tinkivink'

# %%
#teeb ette antud üheelemendilise listi vektoriks
#proovimudel nt get_sum_vector
def proovilistvektoriks(proovimudel, model, lemma_list):
    proovivektor=proovimudel(model, lemma_list.split())
    return proovivektor

proovivektoriks1=proovilistvektoriks(get_sum_vector, model, lemma_list)
# Out:
# C:\Users\sirle\anaconda3\envs\py37\lib\site-packages\ipykernel_launcher.py:5: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   """

# %%
#Loon tabeli, kus on koossiinuse sarnaseimad 200 indeksit, sarnasus ja järjekord (kui sarnane on)
sarnased_maatriks=cosine_similarity(sonad_arrays, proovivektoriks1.reshape(1, -1))
sorteeritud_indeksid=np.argsort(np.squeeze(sarnased_maatriks))
listik_indx=[]
for i in range(1,201):
  listik_indx.append(sorteeritud_indeksid[len(sorteeritud_indeksid) - i])
koos_dist=sarnased_maatriks[listik_indx]
koos_dist_jarj=[]
for i in koos_dist:
    koos_dist_jarj.append(i[0]) 
print(koos_dist_jarj)
print(listik_indx)
tabel_sarnasus = pd.DataFrame(columns=['Kohtuasja_indx', 'Koos_sarnasus', 'Jarjekord'])
tabel_sarnasus['Kohtuasja_indx'] = listik_indx
tabel_sarnasus['Koos_sarnasus'] = koos_dist_jarj
tabel_sarnasus['Jarjekord'] = list(range(1, 201))
Tabel_sarnased=tabel_sarnasus.set_index('Kohtuasja_indx') 
Tabel_sarnased
# Out:
# [0.7667616, 0.72919416, 0.72438186, 0.70494366, 0.70422006, 0.7029946, 0.7020099, 0.70161486, 0.70121956, 0.6962638, 0.69601136, 0.6905795, 0.6905795, 0.6905795, 0.6905795, 0.68837345, 0.68351144, 0.68267727, 0.6822249, 0.6721189, 0.6679719, 0.6676082, 0.66591287, 0.6631464, 0.66241693, 0.6623054, 0.6620879, 0.6607475, 0.6602067, 0.6588863, 0.6576313, 0.6571238, 0.6567235, 0.65659, 0.6561016, 0.65596616, 0.6559425, 0.655788, 0.6550484, 0.65355194, 0.6529304, 0.65236884, 0.65127254, 0.6497358, 0.6497358, 0.64946556, 0.64914274, 0.64856076, 0.64836156, 0.6468321, 0.6468278, 0.64462817, 0.64415073, 0.64404285, 0.6439532, 0.6439532, 0.6422855, 0.64200616, 0.64139104, 0.63922703, 0.63907313, 0.6388882, 0.6387414, 0.63803786, 0.6375071, 0.6356539, 0.6352947, 0.63430107, 0.6336429, 0.6331525, 0.63294315, 0.6328496, 0.63210607, 0.6317294, 0.6312595, 0.6308614, 0.62935805, 0.62911594, 0.62814903, 0.6275691, 0.6275431, 0.6274933, 0.6260918, 0.62599075, 0.6251959, 0.6251425, 0.62509954, 0.6248893, 0.62464666, 0.62436366, 0.62432224, 0.6237935, 0.6237899, 0.6233193, 0.62243474, 0.622203, 0.62214375, 0.6218635, 0.62111163, 0.6209035, 0.6200606, 0.6199584, 0.61993545, 0.61932796, 0.6184975, 0.6184602, 0.6180465, 0.6178028, 0.6176878, 0.61732095, 0.61729467, 0.6170145, 0.6169058, 0.6165546, 0.61608636, 0.61577034, 0.6155547, 0.6154784, 0.6154784, 0.6154784, 0.61508393, 0.6148629, 0.61470175, 0.61465317, 0.6146349, 0.61430407, 0.6140554, 0.6140264, 0.61331856, 0.61255807, 0.61218214, 0.6120825, 0.611817, 0.6117843, 0.6115182, 0.6114527, 0.61140084, 0.61136514, 0.61126435, 0.61093104, 0.6107404, 0.6106801, 0.61059296, 0.61045694, 0.6102642, 0.6102264, 0.61003935, 0.60957956, 0.60957956, 0.6095088, 0.6091964, 0.60901785, 0.60897017, 0.6086551, 0.6085641, 0.60852224, 0.60831004, 0.60829675, 0.60828847, 0.6082635, 0.6079315, 0.6077224, 0.60760254, 0.6075885, 0.60735077, 0.6071971, 0.60704166, 0.606965, 0.60664487, 0.6064501, 0.6064473, 0.60641766, 0.6062472, 0.60623455, 0.6058097, 0.60579014, 0.60577536, 0.6053884, 0.60532886, 0.6051974, 0.60491085, 0.604575, 0.6045514, 0.60448074, 0.604468, 0.6041807, 0.6041588, 0.60396457, 0.60390645, 0.60377026, 0.60376215, 0.6036897, 0.6035466, 0.60335636, 0.60314393, 0.6029961, 0.60297763, 0.60293996, 0.60288894, 0.6028483]
# [141690, 141688, 121904, 280772, 235073, 138763, 69673, 194146, 192853, 44881, 282228, 248570, 248607, 248533, 248496, 235066, 70710, 117749, 232859, 235059, 99372, 226932, 200382, 226933, 141689, 77970, 224032, 225731, 281877, 192848, 194140, 47406, 75330, 239492, 69667, 41183, 24535, 59949, 51738, 282477, 226915, 269963, 278758, 153105, 153118, 277506, 272763, 270660, 262115, 70175, 85137, 272513, 238850, 117762, 228751, 228722, 141719, 146495, 69666, 256518, 69664, 141686, 250245, 238828, 252397, 270801, 85142, 165574, 70704, 277964, 282018, 288148, 166232, 217667, 225707, 245909, 288019, 229244, 277961, 114976, 235368, 12350, 47390, 250244, 217642, 141694, 165567, 12186, 270723, 25068, 235358, 71993, 232852, 255412, 226923, 122291, 187766, 153090, 184446, 141706, 197070, 171901, 270811, 231004, 51740, 37636, 200390, 184478, 165597, 194007, 12157, 173455, 87562, 222883, 47395, 12819, 173451, 288603, 288541, 288572, 197500, 44877, 298046, 250248, 268633, 31354, 135806, 277165, 269957, 6191, 182621, 239173, 143586, 262123, 85138, 259021, 259036, 278330, 282142, 166385, 235335, 10406, 192854, 117054, 273014, 280823, 277958, 153308, 153316, 173478, 94658, 278367, 278164, 197057, 128954, 224033, 117756, 221065, 231467, 235371, 7364, 166236, 248916, 278191, 277180, 268640, 106631, 272835, 283535, 75329, 12353, 41190, 266722, 269291, 220911, 247750, 270258, 99300, 211873, 173450, 153088, 182620, 256964, 47378, 278622, 255182, 128643, 282146, 87040, 266734, 262611, 167117, 49633, 252391, 194142, 272847, 229478, 250276, 272464, 153091]
#                 Koos_sarnasus  Jarjekord
# Kohtuasja_indx
# 141690               0.766762          1
# 141688               0.729194          2
# 121904               0.724382          3
# 280772               0.704944          4
# 235073               0.704220          5
# ...                       ...        ...
# 272847               0.602996        196
# 229478               0.602978        197
# 250276               0.602940        198
# 272464               0.602889        199
# 153091               0.602848        200
#
# [200 rows x 2 columns]

# %%
#Filtreerin indeksite põhjal välja sarnased lõigud
filtreeritud_sarnased=data[data.index.isin(listik_indx)]
filtreeritud_sarnased
# Out:
#                          Tag  \
# 6191    C01PointnumeroteAltN
# 7364    C01PointnumeroteAltN
# 10406   C01PointnumeroteAltN
# 12157   C01PointnumeroteAltN
# 12186   C01PointnumeroteAltN
# ...                      ...
# 288148  C01PointnumeroteAltN
# 288541  C01PointnumeroteAltN
# 288572  C01PointnumeroteAltN
# 288603  C01PointnumeroteAltN
# 298046  C01PointnumeroteAltN
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               Lõigu sisu  \
# 6191                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 54      Sellest tuleneb, et asjaolu, et kauba väliskujundust kaitstakse disainilahendusena, ei välista, et selle kauba kujust koosneva tähise suhtes kehtib kaubamärgiõiguse kaitse, eeldusel, et on täidetud selle tähise kaubamärgina registreerimise tingimused.
# 7364                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             50      Sellest tulenevalt tunnistatakse vastavalt nimetatud artiklitele 15 ja 51 vastava kaubamärgi omaniku õigused tühistatuks, kui kaubamärki ei ole viie aasta jooksul pärast registreerimist liidus tegelikult kasutusele võetud kaupade või teenuste puhul, mille jaoks see on registreeritud. Kui see õiguste tühistamise põhjus on olemas ainult mõne kauba või teenuse puhul, tunnistatakse omaniku õigused tühistatuks ainult sellise kauba või teenuse osas.
# 10406   86      Selles osas tuleb märkida, et nagu nähtub apellatsioonikoja järeldustest vaidlusaluse otsuse punktides 22 ja 23, oli John Millsi ja varasema kaubamärgi omaniku vahel olemas turustusleping, milles nad leppisid kokku, et kaubamärgiomanik tarnib nimetusega „Magic Minerals by Jerome Alexander“ tähistatud kaupu John Millsile ning viimane turustab kaubamärgiomaniku kaupu liidus ja kogu maailmas. John Mills ei ole vastu vaielnud sellele, et lisaks sisaldas see leping tingimusi, mille kohaselt oli John Mills nende kaupade vähemalt eelistatud turustaja, konkurentsikeelu tingimust ja sätteid varasema kaubamärgi omaniku intellektuaalomandiõiguste kohta nende kaupade suhtes. Lisaks kannab viimane tellimusleht, milles John Mills tellis asjaomase kaubamärgi omanikult kaubamärgiga Magic Minerals tähistatud kaupu, kuupäeva, mis vaid ligikaudu kahe kuu võrra eelneb vaidlusaluse kaubamärgi registreerimistaotluse esitamisele.
# 12157                                                                                                                                                                                                                                                                                                                                                                                                           41      Seetõttu tuleb hinnata konkreetselt, peamiselt seoses kaupade või teenustega, mille osas on varasema kaubamärgi omanik tõendanud varasema kaubamärgi kasutamist, kas need kaubad kujutavad endast asjaomasesse kaubaklassi kuuluvate kaupade iseseisvat alamkategooriat selliselt, et need kaubad, mille jaoks varasema kaubamärgi tegelik kasutamine on tõendatud, on seotud kaupade kategooriaga, mida hõlmab selle kaubamärgi registreerimise taotlus (16. juuli 2020. aasta kohtuotsus ACTC vs. EUIPO, C‑714/18 P, EU:C:2020:573, punkt 46).
# 12186                                                                                                                                                                                                                                                                                                                                                      70      On tõsi, nagu märgib ka eelotsusetaotluse esitanud kohus, et 1892. aasta konventsiooni kohaldamine Saksamaa Liitvabariigi poolt võib tekitada raskusi, kuna Saksamaal registreeritud kaubamärgile, mida küll võidakse üksnes selle tegeliku kasutamise tõttu Šveitsi Konföderatsiooni territooriumil registris säilitada, ei saa tugineda selleks, et esitada vastulause ELi kaubamärgi registreerimisele, kuna vastulausemenetluses osutatud kaubamärgi tegeliku kasutamise tõendamise taotluse korral ei saaks selle kaubamärgi omanik sellist kasutamist üksnes liidu territooriumi osas tõendada.
# ...                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  ...
# 288148                                                                                                                                                                                                                                                                                                                                                                                                                                                       42     Peab sedastama, et kuna menetlusse astuja viitas oma kaubamärgi Itaalias registreerimise taotluses kõikide klasside päistele, siis katab see siseriiklik registreerimine kõik nendesse klassidesse kuuluda võivad kaubad. Samamoodi katab tema ühenduse kaubamärgitaotlus ühenduse tasandil kõik klassidesse 11, 19, 20 ja 21 kuuluda võivad kaubad, kuna ta tegi taotluses viite nende klasside päistele. Järelikult segiajamise tõenäosuse hindamiseks tuleb asjaomased kaubad lugeda identseteks.
# 288541                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   56      Kolmandaks, vastupidiselt hageja väitele võib kõnealuste märkide antud asjas registreerimine takistada teiste mõõga masti joonistuste või mängukaartide, mis vastavad hispaania mängukaartide sõjanuiaga rüütlile ja mõõgaga kuningale, registreerimist või kasutamist.
# 288572                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   56      Kolmandaks, vastupidiselt hageja väitele võib kõnealuste märkide antud asjas registreerimine takistada teiste mõõga masti joonistuste või mängukaartide, mis vastavad hispaania mängukaartide sõjanuiaga rüütlile ja mõõgaga kuningale, registreerimist või kasutamist.
# 288603                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   56      Kolmandaks, vastupidiselt hageja väitele võib kõnealuste märkide antud asjas registreerimine takistada teiste mõõga masti joonistuste või mängukaartide, mis vastavad hispaania mängukaartide sõjanuiaga rüütlile ja mõõgaga kuningale, registreerimist või kasutamist.
# 298046                                                                                                                                                                                                                                                                                                                                                                                                         55     Vastulause aluseks on varasem kaubamärk, mis on registreeritud kõikide klassi 35 kuuluvate teenuste jaoks, ja vastulause on suunatud taotletava kaubamärgi registreerimise vastu ühest küljest klassi 35 kuuluvate teenuste ja teisest küljest klassi 41 kuuluvate teenuste osas (vt eespool punktid 7–9). Seega võib asuda kahe võrdluse juurde, millest ühe puhul võetakse arvesse kaubamärgi taotluses märgitud teenuseid, mis kuuluvad klassi 35, ja teise puhul võetakse arvesse selles taotluses märgitud teenuseid, mis kuuluvad klassi 41.
#
#        Pealkiri1          Kohtuasja_nr  Kohtuasja_ID algus_lopp  \
# 6191         NaN              C‑237/19           230      algus
# 7364         NaN            C‑143/19 P           278      algus
# 10406        NaN            C‑809/18 P           383      algus
# 12157        NaN  C‑720/18 ja C‑721/18           436      algus
# 12186        NaN  C‑720/18 ja C‑721/18           436      algus
# ...          ...                   ...           ...        ...
# 288148       NaN              T-186/02         20341      algus
# 288541       NaN     T-160/02–T-162/02         20360      algus
# 288572       NaN     T-160/02–T-162/02         20361      algus
# 288603       NaN     T-160/02–T-162/02         20362      algus
# 298046       NaN              T-317/01         20509      algus
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     stop_eemaldatud  \
# 6191                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     54 tuleneb asjaolu kauba väliskujundust kaitstakse disainilahendusena välista kauba kujust koosneva tähise kehtib kaubamärgiõiguse kaitse eeldusel täidetud tähise kaubamärgina registreerimise tingimused
# 7364                                                                                                                                                                                                                                                                                                                                                                                                               50 tulenevalt tunnistatakse vastavalt nimetatud artiklitele 15 51 vastava kaubamärgi omaniku õigused tühistatuks kaubamärki viie aasta registreerimist liidus tegelikult kasutusele võetud kaupade teenuste registreeritud õiguste tühistamise põhjus kauba teenuse tunnistatakse omaniku õigused tühistatuks kauba teenuse osas
# 10406   86 osas märkida nähtub apellatsioonikoja järeldustest vaidlusaluse otsuse punktides 22 23 john millsi varasema kaubamärgi omaniku turustusleping leppisid kaubamärgiomanik tarnib nimetusega „ magic minerals by jerome alexander “ tähistatud kaupu john millsile viimane turustab kaubamärgiomaniku kaupu liidus maailmas john mills vaielnud sisaldas leping tingimusi john mills kaupade eelistatud turustaja konkurentsikeelu tingimust sätteid varasema kaubamärgi omaniku intellektuaalomandiõiguste kaupade kannab viimane tellimusleht john mills tellis asjaomase kaubamärgi omanikult kaubamärgiga magic minerals tähistatud kaupu kuupäeva ligikaudu kahe kuu eelneb vaidlusaluse kaubamärgi registreerimistaotluse esitamisele
# 12157                                                                                                                                                                                                                                                                                                               41 hinnata konkreetselt seoses kaupade teenustega osas varasema kaubamärgi omanik tõendanud varasema kaubamärgi kasutamist kaubad kujutavad asjaomasesse kaubaklassi kuuluvate kaupade iseseisvat alamkategooriat kaubad varasema kaubamärgi tegelik kasutamine tõendatud seotud kaupade kategooriaga hõlmab kaubamärgi registreerimise taotlus 16. juuli 2020. aasta kohtuotsus actc vs. euipo c‑714/18 eu c:2020:573 punkt 46
# 12186                                                                                                                                                                                                                                                                70 tõsi märgib eelotsusetaotluse esitanud kohus 1892. aasta konventsiooni kohaldamine saksamaa liitvabariigi tekitada raskusi saksamaal registreeritud kaubamärgile üksnes tegeliku kasutamise šveitsi konföderatsiooni territooriumil registris säilitada tugineda esitada vastulause eli kaubamärgi registreerimisele vastulausemenetluses osutatud kaubamärgi tegeliku kasutamise tõendamise taotluse kaubamärgi omanik kasutamist üksnes liidu territooriumi osas tõendada
# ...                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             ...
# 288148                                                                                                                                                                                                                                                                                                                                                             42 sedastama menetlusse astuja viitas kaubamärgi itaalias registreerimise taotluses klasside päistele katab siseriiklik registreerimine klassidesse kuuluda kaubad samamoodi katab ühenduse kaubamärgitaotlus ühenduse tasandil klassidesse 11 19 20 21 kuuluda kaubad taotluses viite klasside päistele segiajamise tõenäosuse hindamiseks asjaomased kaubad lugeda identseteks
# 288541                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  56 kolmandaks vastupidiselt hageja väitele kõnealuste märkide antud asjas registreerimine takistada mõõga masti joonistuste mängukaartide vastavad hispaania mängukaartide sõjanuiaga rüütlile mõõgaga kuningale registreerimist kasutamist
# 288572                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  56 kolmandaks vastupidiselt hageja väitele kõnealuste märkide antud asjas registreerimine takistada mõõga masti joonistuste mängukaartide vastavad hispaania mängukaartide sõjanuiaga rüütlile mõõgaga kuningale registreerimist kasutamist
# 288603                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  56 kolmandaks vastupidiselt hageja väitele kõnealuste märkide antud asjas registreerimine takistada mõõga masti joonistuste mängukaartide vastavad hispaania mängukaartide sõjanuiaga rüütlile mõõgaga kuningale registreerimist kasutamist
# 298046                                                                                                                                                                                                                                                                                                                                                 55 vastulause aluseks varasem kaubamärk registreeritud klassi 35 kuuluvate teenuste vastulause suunatud taotletava kaubamärgi registreerimise klassi 35 kuuluvate teenuste klassi 41 kuuluvate teenuste osas vt punktid 7–9 asuda kahe võrdluse võetakse arvesse kaubamärgi taotluses märgitud teenuseid kuuluvad klassi 35 võetakse arvesse taotluses märgitud teenuseid kuuluvad klassi 41
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         Lemma
# 6191                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 54 tulenema asjaolu kaup väliskujundus kaitsma disainilahendus välistama kaup kuju koosnev tähis kehtima kaubamärgiõigus kaitse eeldus täidetud tähis kaubamärk registreerimine tingimus
# 7364                                                                                                                                                                                                                                                                                                                                                                                                 50 tulenevalt tunnistama vastavalt nimetama artikkel 15 51 vastav kaubamärk omanik õigus tühistatu kaubamärk viis aasta registreerimine liit tegelikult kasutus võetud kaup teenus registreerima õigus tühistamine põhjus kaup teenus tunnistama omanik õigus tühistama kaup teenus osas
# 10406   86 osa märkima nähtuma apellatsioonikoda järeldus vaidlusalune otsus punkt 22 23 john mills varasem kaubamärk omanik turustusleping leppima kaubamärgiomanik tarnima nimetus „ magic minerals by jerome alexander “ tähistama kaup john mills viimane turustama kaubamärgiomanik kaup liit maailm john mills vaidlema sisaldama leping tingimus john mills kaup eelistama turustaja konkurentsikeeld tingimus säte varasem kaubamärk omanik intellektuaalomandiõigus kaup kandma viimane tellimusleht john mills tellima asjaomane kaubamärk omanik kaubamärk magic minerals tähistama kaup kuupäev ligikaudu kaks kuu eelnema vaidlusalune kaubamärk registreerimistaotlus esitamine
# 12157                                                                                                                                                                                                                                                                                      41 hindama konkreetselt seoses kaup teenus osa varasem kaubamärk omanik tõendama varasem kaubamärk kasutamine kaup kujutama asjaomane kaubaklass kuuluv kaup iseseisev alamkategooria kaup varasem kaubamärk tegelik kasutamine tõendama seotud kaup kategooria hõlmama kaubamärk registreerimine taotlus 16. juuli 2020. aasta kohtuotsus actc vs . euipo c ‑ 714 / 18 eu c : 2020 : 573 punkt 46
# 12186                                                                                                                                                                                                                                    70 tõsi märkima eelotsusetaotlus esitama kohus 1892. aasta konventsioon kohaldamine saksamaa liitvabariik tekitama raskus saksamaa registreerima kaubamärk üksnes tegelik kasutamine šveitsi konföderatsioon territoorium register säilitama tuginema esitama vastulause eli kaubamärk registreerimine vastulausemenetlus osutama kaubamärk tegelik kasutamine tõendamine taotlus kaubamärk omanik kasutamine üksnes liit territoorium osas tõendama
# ...                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       ...
# 288148                                                                                                                                                                                                                                                                                                                                                             42 sedastama menetlus astuja viitama kaubamärk itaalia registreerimine taotlus klass päis katma siseriiklik registreerimine klass kuuluma kaup samamoodi katma ühendus kaubamärgitaotlus ühendus tasand klass 11192021 kuuluma kaup taotlus viide klass päis segiajamine tõenäosus hindamine asjaomane kaup lugema identne
# 288541                                                                                                                                                                                                                                                                                                                                                                                                                                                                            56 kolmas vastupidiselt hageja väide kõnealune märk andma asi registreerimine takistama mõõk mast joonistus mängukaart vastama hispaania mängukaart sõjanui rüütel mõõk kuningas registreerimine kasutamine
# 288572                                                                                                                                                                                                                                                                                                                                                                                                                                                                            56 kolmas vastupidiselt hageja väide kõnealune märk andma asi registreerimine takistama mõõk mast joonistus mängukaart vastama hispaania mängukaart sõjanui rüütel mõõk kuningas registreerimine kasutamine
# 288603                                                                                                                                                                                                                                                                                                                                                                                                                                                                            56 kolmas vastupidiselt hageja väide kõnealune märk andma asi registreerimine takistama mõõk mast joonistus mängukaart vastama hispaania mängukaart sõjanui rüütel mõõk kuningas registreerimine kasutamine
# 298046                                                                                                                                                                                                                                                                                                                                               55 vastulause alune varasem kaubamärk registreerima klass 35 kuuluv teenus vastulause suunama taotletav kaubamärk registreerimine klass 35 kuuluv teenus klass 41 kuuluv teenus osas vt punkt 7 - 9 asuma kaks võrdlus võtma arve kaubamärk taotlus märgitud teenus kuuluma klass 35 võtma arve taotlus märgitud teenus kuuluma klass 41
#
# [200 rows x 8 columns]

# %%
# Ühendan kaks tabelit ja filtreerin välja Koos_sarnasus,	Jarjekord, Lõigu sisu, Kohtuasja_nr
Tulemus = pd.concat([Tabel_sarnased, filtreeritud_sarnased], axis=1)
Uus = (Tulemus[['Koos_sarnasus', 'Jarjekord','Tag','Lõigu sisu', 'Pealkiri1','Kohtuasja_nr','Kohtuasja_ID', 'algus_lopp', 'Lemma']]).sort_values('Jarjekord', ascending=True)
Uus['Indeks'] = Uus.index
Uus
# Out:
#         Koos_sarnasus  Jarjekord  \
# 141690       0.766762          1
# 141688       0.729194          2
# 121904       0.724382          3
# 280772       0.704944          4
# 235073       0.704220          5
# ...               ...        ...
# 272847       0.602996        196
# 229478       0.602978        197
# 250276       0.602940        198
# 272464       0.602889        199
# 153091       0.602848        200
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               Lõigu sisu  \
# 141690                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              58      Neljandaks peab varasema kaubamärgi omanik olema teadlik hilisema kaubamärgi registreerimisest ja selle kasutamisest pärast registreerimist.
# 141688                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           56      Teiseks peab hilisema kaubamärgi registreerimise taotleja tegutsema heauskselt.
# 121904                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    57      Nagu nähtub eelotsusetaotlusest, loetakse registreerimine kui mahaarvamisõiguse kasutamise tingimus toimunuks alates kuupäevast, mil selle kohta on väljastatud registreerimist käsitlev otsus, mitte alates maksukohustuslasena registreerimise avalduse esitamisest.
# 280772                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      50      Sellest järeldub, et füüsilise isiku eesnime ja perekonnanimesid sisaldavat tähist ei registreerita ühenduse kaubamärgina, kui varasema kaubamärgi omaniku vastulause tõttu kohaldatakse registreerimise suhtelist keeldumispõhjust.
# 235073                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     53      Hageja peab seega tõendama, et kaubamärgi registreerimise taotluse esitamise kuupäeval oli tema viidatud varasem kaubamärk JOSE PADILLA mõnes liikmesriigis üldtuntud ja seda kasutati identsete või sarnaste toodete jaoks kui need, mille osas taotleti kaubamärgi registreerimist.
# ...                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  ...
# 272847                                                                                                                                                                                                                                                                                                                       59      Hageja märgib, et mitu kolmandate riikide, nagu Austraalia ja Ameerika Ühendriigid, kaubamärgi valdkonna pädevat ametiasutust on registreerinud kaubamärgi LIVE RICHLY Nizza kokkuleppe klassi 36 kuuluvate samade teenuste jaoks. Mööndes, et Ameerika Ühendriigid ja Austraalia ei ole liikmesriigid, leiab hageja ometi, et nimetatud kaubamärgi LIVE RICHLY registreeringud on oluline näide selle kaubamärgi registreerimise võimalikkusest inglise keelt kõnelevates maades.
# 229478                                                                                                                                                                                                                                                                                                                                                                                                            89      Peale selle annab registreeritud kaubamärk selle omanikule teatavate kaupade või teenustega seoses ainuõiguse, mille alusel ta saab ajaliste piiranguteta seda kaubamärgina registreeritud tähist monopoliseerida, kuid kaubamärgi registreerimise võimalusele võib seada üldisel huvil tuginevaid piiranguid (vt selle kohta eespool punktis 88 viidatud kohtuotsus Libertel, punktid 49–50).
# 250276  85      Seoses Kanada kaubamärgiameti väidetavalt vähem kitsendava praktikaga tuleb märkida, et hageja ei ole tõendanud ega isegi ühemõtteliselt väitnud, et Kanada pädevad asutused on nõustunud tema taotletud kaubamärgi registreerimisega. Hageja väidetud asjaolu, et ta on Kanadas esitanud taotletud kaubamärgiga identse kaubamärgi registreerimise taotluse, mille ta hiljem Pariisi konventsiooni artiklist 6 ter sõltumatutel põhjustel tagasi võttis, ei tõenda, et registreerimisega oleks nõustutud. Olukorras, kus taotletud kaubamärk ei ole Kanadas lõplikult registreeritud, ei ole sugugi kindel, et Kanada asutused ei oleks registreerimismenetluse hilisemas staadiumis esitanud vastuväidet selle kohta, et taotletud kaubamärk kujutab sama vahtralehte, mis on Kanada riigi embleemiks.
# 272464                                                                                                                                                                                                          19      Määruse nr 40/94 artikli 8 lõige 5 sätestab, et „[l]õike 2 tähenduses varasema kaubamärgi omaniku vastuseisu korral ei registreerita taotletavat kaubamärki, kui see on identne või sarnane varasema kaubamärgiga ning seda tahetakse registreerida kaupade või teenuste jaoks, mis ei ole sarnased nendega, mille jaoks on registreeritud varasem kaubamärk, kui varasema ühenduse kaubamärgi olemasolul on see omandanud ühenduses maine […] kui taotletava kaubamärgi kasutamine ilma tungiva põhjuseta tähendaks varasema kaubamärgi eristusvõime või maine ärakasutamist või kahjustamist”.
# 153091                                                                                                                                                                                                                                                                                                                                                                                                                                            69      Kui põhikohtuasja hageja ei oleks registreerinud sõnamärki, oleks ta pidanud ootama tippdomeeni .eu domeeninimede üldise registreerimise algust, riskides nii – nagu ka kõik teised samast domeeninimest huvitatud isikud – sellega, et taotluste saabumise järjekorra põhimõtte alusel on temast eespool enne tema registreerimise taotlust esitatud taotlus.
#
#        Kohtuasja_nr
# 141690     C‑482/09
# 141688     C‑482/09
# 121904     C‑284/11
# 280772      T‑40/03
# 235073     T‑255/08
# ...             ...
# 272847     T-320/03
# 229478     T‑258/09
# 250276     T‑215/06
# 272464     T-336/03
# 153091     C‑569/08
#
# [200 rows x 4 columns]

# %%
# Salvestame tulemuse:
#Word2vec_tulemus_lemmatud.csv
#Word2vec_tulemus_ilma_resota_lemmatud.csv
#Word2vec_tulemus_ainult_reso_lemmatud.csv
#Uus.to_csv("Word2vec_tulemus_lemmatud.csv", index=False)
